# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('extended_salary_data.csv')
df.head()
# Out:
#    YearsExperience     Salary
# 0              8.1   77884.67
# 1             19.1  127213.68
# 2             14.9  103343.52
# 3             12.4   88988.96
# 4              4.0   35214.78

# %%
plt.scatter(df['YearsExperience'],df['Salary'])
plt.xlabel('Years of Experience')
plt.ylabel('Salary of Employee')
plt.title('Salary vs Years of Experience')
# Out:
# Text(0.5, 1.0, 'Salary vs Years of Experience')

# %%
mean_1 = df['YearsExperience'].mean()
mean_1
# Out:
# np.float64(9.48)

# %%
median_1 = df['YearsExperience'].median()
median_1
# Out:
# 9.3

# %%
var_1 = df['YearsExperience'].var()
var_1
# Out:
# 30.09061224489795

# %%
mean_2 = df['Salary'].mean()
mean_2
# Out:
# np.float64(77370.5474)

# %%
median_2 = df['Salary'].median()
median_2
# Out:
# 78598.65

# %%
var_2 = df['Salary'].var()
var_2
# Out:
# 800829123.3381461

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df[['YearsExperience']],df['Salary'],test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([4912.76821009])

# %%
model.intercept_
# Out:
# np.float64(31102.513724263103)

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([124445.10971596,  64509.33755287,  93003.39317139,  82195.30310919,
#        109215.52826468, 121006.17196889,  65000.61437388, 125918.94017898,
#         70404.65940498, 104302.76005459])

# %%
model.score(X_test,y_test)
# Out:
# 0.7871637434342427

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score
mean_squared_error(y_test,y_pred)
# Out:
# 147476801.66301695

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 9940.531686799526

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7871637434342427
